# %%
import tabs

# %%
df=tabs.read('08189500', '2010-1-1', '2012-1-1')

# %%
df.plot()

# %%
df2 = tabs.read('V', '2010-1-1', '2010-1-2' )

# %%
df2['V: WaveHeight [m]'].plot()

# %%
df2 = tabs.read('V', '2018-6-2', '2018-6-10', model=True, s_rho=-1)
# Out:
# Exception:
#  No columns to parse from file
#
# None returned

# %%
pwd
# Out:
# '/home/dylan'

# %%
from glob import glob
Files = glob('*/*output*.nc')
year = 2010
glob('/d2/copano_bay/%s_n/*_%s/output_*.nc' %(str(year),str(year)))

# %%
df_wind=tabs.read('MARCEMET', '2010-1-1', '2012-1-1') #Meterological Data available for 8774513
# Out:
# Exception:
#  400 Client Error: Invalid Site number format: character is not a digit at argument 0, position 0, server=[sdas01] for url: https://waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=MARCEMET&parameterCd=00060&startDT=2010-01-01&endDT=2012-01-01
#
# None returned
# /opt/anaconda3/lib/python3.6/site-packages/hydrofunctions/hydrofunctions.py:422: SyntaxWarning: The NWIS returned a code of 400.
# 400 Bad Request - This often occurs if the URL arguments are inconsistent, for example in the instantaneous values service using startDT and endDT with the period argument. An accompanying error should describe why the request was bad.
# Error message from NWIS: Invalid Site number format: character is not a digit at argument 0, position 0, server=[sdas01]
#
# URL used in this request: https://waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=MARCEMET&parameterCd=00060&startDT=2010-01-01&endDT=2012-01-01
#   warnings.warn(msg, SyntaxWarning)

# %%
df_wind
# Out:
#                            8774513: AirT [deg C]  8774513: AtmPr [mb]  \
# Dates [UTC]
# 2010-01-09 14:54:00+00:00                    NaN                  NaN
# 2010-01-09 15:00:00+00:00                    NaN                  NaN
# 2010-01-09 15:06:00+00:00                    NaN                  NaN
# 2010-01-09 15:12:00+00:00                    NaN                  NaN
# 2010-01-09 15:18:00+00:00                    NaN                  NaN
# 2010-01-09 15:24:00+00:00                    NaN                  NaN
# 2010-01-09 15:30:00+00:00                    NaN                  NaN
# 2010-01-09 15:36:00+00:00                    NaN                  NaN
# 2010-01-09 15:42:00+00:00                    NaN                  NaN
# 2010-01-09 15:48:00+00:00                    NaN                  NaN
# 2010-01-09 15:54:00+00:00                    NaN                  NaN
# 2010-01-09 16:00:00+00:00                    NaN                  NaN
# ...
